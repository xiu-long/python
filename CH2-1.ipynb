# %%
#!/usr/bin/env python
# coding: utf-8

# ## python資料表示與運算

# ## 註解

# In[1]:


# CH2
a=3
b=2
print(a+b)


# In[ ]:


'''
多行註解
...
'''

a=3
b=2
a,b=b,a
print(a,b)


# In[2]:


# 兩數交換
x=1
y=10
z=x
x=y
y=z
print(x)
print(y)


# In[3]:


x,y,z=3,4,5
print(x)
print(y)
print(z)



# In[4]:


x,y,z=3,4,5
x+=1 #x=x+1
y*=2 #y=y*2
z**=3#z=z*z*z
print(x,y,z)




# In[7]:


import math
a,b,c=3,4,5
s=(a+b+c)/2
area=math.sqrt(s*(s-a)*(s-b)*(s-c)) #傳回指定數字的平方根
print(area)


# #  python 使用動態類型變數 不用宣告資料型態

# In[9]:


x=254
print(type(x))
y='covid-19'
print(type(y))
print(id(x),id(y))


# # 半徑

# In[10]:


import math
print((4.5*4.5*math.pi*4.5)/3)


# In[11]:


x,y =16,3
print(x/y) #求值
print(x//y) #求商
print(x%y)   #求於數


# # 關係運算

# In[14]:


print (20==20)
x,y=10,20
print (x==y)
x=y
print(x)


# # 級聯比較

# # 4年一潤 100年不潤 400年在潤

# In[16]:


a,b,c=10,20,30
print(a<=b<=c)


# In[15]:


x=3.141592627
print (x-3.14)


# # 邏輯運算 閏年範例

# In[17]:


y=2020
print(y%4==0 and y%100!=0 or y%400==0)
y=2000
print(y%4==0 and y%100!=0 or y%400==0)
y=1900
print(y%4==0 and y%100!=0 or y%400==0)
y=2019
print(y%4==0 and y%100!=0 or y%400==0)
# Out:
# 5
# 2 3
# 10
# 1
# 3
# 4
# 5
# 4 8 125
# 6.0
# <class 'int'>
# <class 'str'>
# 140734091346224 1712340409840
# 95.42587685278995
# 5.333333333333333
# 5
# 1
# True
# False
# 20
# True
# 0.0015926269999999576
# True
# True
# False
# False
